# %%
#Import libraries 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df = pd.read_csv("../csse_covid_19_time_series/time_series_covid19_confirmed_global.csv")

df.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20   ...    3/27/20  3/28/20  3/29/20  3/30/20  \
# 0        0        0        0   ...        110      110      120      170
# 1        0        0        0   ...        186      197      212      223
# 2        0        0        0   ...        409      454      511      584
# 3        0        0        0   ...        267      308      334      370
# 4        0        0        0   ...          4        5        7        7
#
#    3/31/20  4/1/20  4/2/20  4/3/20  4/4/20  4/5/20
# 0      174     237     273     281     299     349
# 1      243     259     277     304     333     361
# 2      716     847     986    1171    1251    1320
# 3      376     390     428     439     466     501
# 4        7       8       8       8      10      14
#
# [5 rows x 79 columns]

# %% [markdown]
# The data needs to be transformed for it to be useful.

# %%
# Transform the data using padas melt
df_melt = pd.melt(df, id_vars=['Province/State', 'Country/Region', 'Lat', 'Long'], var_name='date', value_name='numcases')
df_melt.tail(5)
# Out:
#                           Province/State  Country/Region        Lat  \
# 19645                                NaN          Malawi -13.254308
# 19646  Falkland Islands (Islas Malvinas)  United Kingdom -51.796300
# 19647          Saint Pierre and Miquelon          France  46.885200
# 19648                                NaN     South Sudan   6.877000
# 19649                                NaN  Western Sahara  24.215500
#
#             Long    date  numcases
# 19645  34.301525  4/5/20         4
# 19646 -59.523600  4/5/20         2
# 19647 -56.315900  4/5/20         1
# 19648  31.307000  4/5/20         1
# 19649 -12.885800  4/5/20         4

# %%
#Replace NaN values with empty string
df_melt = df_melt.fillna('')
df_melt.isnull().sum()
# Out:
# Province/State    0
# Country/Region    0
# Lat               0
# Long              0
# date              0
# numcases          0
# dtype: int64

# %%
df_melt[df_melt['Country/Region']=="Algeria"].plot(x='date', y='numcases');

# %%
# Export transformed data as CSV
df_melt.to_csv("transformed-data/transformed-global-confirmed-cases.csv", index=False)

# %%
# Compare number of confirmed cases as of 4/1/20
df_melt[df_melt['date']=='4/1/20'].groupby('Country/Region').sum()['numcases'].sort_values(ascending=True).plot(kind='barh', figsize=(20,50), rot=45);
plt.title("Number of Confirmed Cases");
plt.xlabel("Country");
