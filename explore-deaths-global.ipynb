# %%
#Import libraries 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df = pd.read_csv("csse_covid_19_time_series/time_series_covid19_deaths_global.csv")
df.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20   ...    3/27/20  3/28/20  3/29/20  3/30/20  \
# 0        0        0        0   ...          4        4        4        4
# 1        0        0        0   ...          8       10       10       11
# 2        0        0        0   ...         26       29       31       35
# 3        0        0        0   ...          3        3        6        8
# 4        0        0        0   ...          0        0        2        2
#
#    3/31/20  4/1/20  4/2/20  4/3/20  4/4/20  4/5/20
# ...

# %% [markdown]
# The data needs to be transformed for it to be useful.

# %%
# Transform the data using padas melt
df_melt = pd.melt(df, id_vars=['Province/State', 'Country/Region', 'Lat', 'Long'], var_name='date', value_name='numdeaths')
df_melt.tail(10)
# Out:
#                           Province/State  Country/Region        Lat  \
# 19640                                NaN      MS Zaandam   0.000000
# 19641                                NaN        Botswana -22.328500
# 19642                                NaN         Burundi  -3.373100
# 19643                                NaN    Sierra Leone   8.460555
# 19644   Bonaire, Sint Eustatius and Saba     Netherlands  12.178400
# 19645                                NaN          Malawi -13.254308
# 19646  Falkland Islands (Islas Malvinas)  United Kingdom -51.796300
# 19647          Saint Pierre and Miquelon          France  46.885200
# 19648                                NaN     South Sudan   6.877000
# 19649                                NaN  Western Sahara  24.215500
#
#             Long    date  numdeaths
# 19640   0.000000  4/5/20          2
# 19641  24.684900  4/5/20          1
# 19642  29.918900  4/5/20          0
# 19643 -11.779889  4/5/20          0
# ...

# %%
df_melt[df_melt['Country/Region']=="Algeria"].plot(x='date', y='numdeaths', 
                                                   linewidth=2, figsize=(20,5), rot=45);
plt.title("Number of deaths", fontsize=14); 
plt.xlabel('Day', fontsize=14)
# Out:
# Text(0.5, 0, 'Day')

# %%
# Export transformed data as CSV
df_melt.to_csv("transformed-data/transformed-global-covid19-deaths.csv", index=False)
